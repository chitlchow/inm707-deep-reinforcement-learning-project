# %% [markdown]
# # Result Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
training_data = pd.read_csv('result-dataset/training_history-(0.01, 0.95, 0.9992).csv')

# %%
training_data.plot(x='Episodes', y=['Score'], kind='line')
plt.ylabel('Score')
# Out:
# Text(0, 0.5, 'Score')

# %%
training_data.plot(x='Episodes', y='Epsilon')
# Out:
# <Axes: xlabel='Episodes'>
